# %%
import requests

response = requests.get("http://127.0.0.1:8000/api/v1/posts/")
print(response.status_code)
print(response.json())
# Out:
# 200
# [{'id': 1, 'title': 'My First Post', 'content': 'This is my first blog post', 'status': 'draft', 'author': 1}]
